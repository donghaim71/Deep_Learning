# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
import matplotlib.pyplot as plt
import numpy as np


# MNIST 데이터 셋을 호출
(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255


# 생성자 모델 만들기
autoencoder = Sequential()


# 인코딩 부분
autoencoder.add(Conv2D(16, kernel_size=3, padding='same', input_shape=(28, 28, 1), activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu'))


# 디코딩 부분
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))


# 전체 구조 확인
autoencoder.summary()


# 컴파일 및 학습을 하는 부분
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_test, X_test))


# 학습된 결과를 출력하는 부분
random_test = np.random.randint(X_test.shape[0], size=5)


# 테스트할 이미지를 랜덤으로 호출
ae_imgs = autoencoder.predict(X_test) # 앞서 만든 오토인코더 모델에 넣기


plt.figure(figsize=(7, 2)) # 출력 이미지 크기 정하기


for i, image_idx in enumerate(random_test):
  # 랜덤으로 뽑은 이미지를 차례로 나열
  ax = plt.subplot(2, 7, i + 1)
  # 테스트할 이미지를 먼저 그대로 보여줌
  plt.imshow(X_test[image_idx].reshape(28, 28))
  ax.axis('off')
  ax = plt.subplot(2, 7, 7 +i +1)
  # 오토인코딩 결과를 다음 열에 입력
  plt.imshow(ae_imgs[image_idx].reshape(28, 28))
  ax.axis('off')
plt.show()
# Out:
# Model: "sequential_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_66 (Conv2D)          (None, 28, 28, 16)        160
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  conv2d_67 (Conv2D)          (None, 14, 14, 8)         1160
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 8)          0
#  2D)
#
#  conv2d_68 (Conv2D)          (None, 4, 4, 8)           584
#
#  conv2d_69 (Conv2D)          (None, 4, 4, 8)           584
#
#  up_sampling2d_35 (UpSamplin  (None, 8, 8, 8)          0
#  g2D)
#
#  conv2d_70 (Conv2D)          (None, 8, 8, 8)           584
#
#  up_sampling2d_36 (UpSamplin  (None, 16, 16, 8)        0
#  g2D)
#
#  conv2d_71 (Conv2D)          (None, 14, 14, 16)        1168
#
#  up_sampling2d_37 (UpSamplin  (None, 28, 28, 16)       0
#  g2D)
#
#  conv2d_72 (Conv2D)          (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2049 - val_loss: 0.1342
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1245 - val_loss: 0.1161
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1134 - val_loss: 0.1089
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1076 - val_loss: 0.1055
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1037 - val_loss: 0.1009
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1006 - val_loss: 0.0982
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0983 - val_loss: 0.0963
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0964 - val_loss: 0.0943
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0949 - val_loss: 0.0930
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0919
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0926 - val_loss: 0.0914
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0916 - val_loss: 0.0900
# Epoch 13/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0908 - val_loss: 0.0891
# Epoch 14/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0900 - val_loss: 0.0893
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0894 - val_loss: 0.0878
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0887 - val_loss: 0.0872
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0882 - val_loss: 0.0867
# Epoch 18/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0877 - val_loss: 0.0862
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0871 - val_loss: 0.0857
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0867 - val_loss: 0.0856
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0863 - val_loss: 0.0849
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0859 - val_loss: 0.0846
# Epoch 23/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0856 - val_loss: 0.0845
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0853 - val_loss: 0.0843
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0850 - val_loss: 0.0839
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0848 - val_loss: 0.0837
# Epoch 27/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0845 - val_loss: 0.0834
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0843 - val_loss: 0.0832
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0841 - val_loss: 0.0828
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0840 - val_loss: 0.0827
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0838 - val_loss: 0.0826
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0836 - val_loss: 0.0826
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0834 - val_loss: 0.0829
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0834 - val_loss: 0.0823
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0832 - val_loss: 0.0823
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0831 - val_loss: 0.0820
# Epoch 37/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0829 - val_loss: 0.0819
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0828 - val_loss: 0.0818
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0827 - val_loss: 0.0817
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0826 - val_loss: 0.0815
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0824 - val_loss: 0.0813
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0823 - val_loss: 0.0811
# Epoch 43/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0822 - val_loss: 0.0812
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0821 - val_loss: 0.0812
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0820 - val_loss: 0.0808
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0818 - val_loss: 0.0811
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0817 - val_loss: 0.0806
# Epoch 48/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0816 - val_loss: 0.0806
# Epoch 49/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0815 - val_loss: 0.0806
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0814 - val_loss: 0.0804
