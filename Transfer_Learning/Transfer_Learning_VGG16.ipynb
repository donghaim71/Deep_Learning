# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Input, models, layers, optimizers, metrics
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.applications import VGG16

np.random.seed(3)
tf.compat.v1.set_random_seed(3)

train_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,    # 수평 대칭 이미지를 50% 확률로 만들어 추가
                                   width_shift_range=0.1,   # 전체 크기의 10% 범위에서 좌우로 이동
                                   height_shift_range=0.1,  # 마찬가지로 위아래로 이동
                                                            # rotaion_range=5,
                                                            # shear_range=0.7,
                                                            # zoom_range=[0.9, 2.2],
                                                            # vertical_flip=True,
                                   fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(
    './train',  # 학습셋이 있는 폴더 위치
    target_size=(150, 150),
    batch_size=5,
    class_mode='binary')

# 테스트셋은 이미지 부풀리기 과정을 진행하지 않음
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    './test', # 테스트셋이 있는 폴더 위치
    target_size=(150, 150),
    batch_size=5,
    class_mode='binary'
)

transfer_model = VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
transfer_model.trainable = False
transfer_model.summary()
finetune_model = models.Sequential()
finetune_model.add(transfer_model)
finetune_model.add(Flatten())
finetune_model.add(Dense(64, activation='relu'))
finetune_model.add(Dense(2, activation='softmax'))
finetune_model.summary()

# 모델 컴파일
finetune_model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizers.Adam(learning_rate=0.0002), metrics=['accuracy'])

# 모델 실행
history = finetune_model.fit_generator(
    train_generator,
    steps_per_epoch=30,
    epochs=50,
    validation_data=test_generator,
    validation_steps=10)

# 결과를 그래프로 표현하는 부분
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))
plt.plot(x_len, acc, marker='.', c="red", label='Trainset_acc')
plt.plot(x_len, val_acc, marker='.', c="lightcoral", label='Testset_acc')
plt.plot(x_len, y_vloss, marker='.', c="cornflowerblue", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()
# Out:
# Found 160 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_21 (Flatten)        (None, 8192)              0
#
#  dense_41 (Dense)            (None, 64)                524352
#
#  dense_42 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 15,239,170
# Trainable params: 524,482
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:59: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 30/30 [==============================] - 2s 54ms/step - loss: 0.6490 - accuracy: 0.6600 - val_loss: 0.5663 - val_accuracy: 0.7000
# Epoch 2/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.4090 - accuracy: 0.8600 - val_loss: 0.3755 - val_accuracy: 0.8800
# Epoch 3/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.3264 - accuracy: 0.9000 - val_loss: 0.3550 - val_accuracy: 0.8200
# Epoch 4/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.2382 - accuracy: 0.9267 - val_loss: 0.2938 - val_accuracy: 0.8400
# Epoch 5/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.2233 - accuracy: 0.9400 - val_loss: 0.2044 - val_accuracy: 0.9600
# Epoch 6/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1767 - accuracy: 0.9600 - val_loss: 0.2607 - val_accuracy: 0.8800
# Epoch 7/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.1487 - accuracy: 0.9533 - val_loss: 0.1792 - val_accuracy: 0.9200
# Epoch 8/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1456 - accuracy: 0.9600 - val_loss: 0.1174 - val_accuracy: 0.9800
# Epoch 9/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1391 - accuracy: 0.9600 - val_loss: 0.1347 - val_accuracy: 0.9800
# Epoch 10/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1184 - accuracy: 0.9733 - val_loss: 0.1718 - val_accuracy: 0.9600
# Epoch 11/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.1352 - accuracy: 0.9467 - val_loss: 0.1030 - val_accuracy: 1.0000
# Epoch 12/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1068 - accuracy: 0.9733 - val_loss: 0.2540 - val_accuracy: 0.8600
# Epoch 13/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0939 - accuracy: 0.9800 - val_loss: 0.1179 - val_accuracy: 0.9800
# Epoch 14/50
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0819 - accuracy: 0.9800 - val_loss: 0.1241 - val_accuracy: 0.9600
# Epoch 15/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0975 - accuracy: 0.9667 - val_loss: 0.1668 - val_accuracy: 0.9600
# Epoch 16/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0805 - accuracy: 0.9867 - val_loss: 0.0759 - val_accuracy: 0.9800
# Epoch 17/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1089 - accuracy: 0.9733 - val_loss: 0.0912 - val_accuracy: 0.9600
# Epoch 18/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0655 - accuracy: 0.9800 - val_loss: 0.0606 - val_accuracy: 1.0000
# Epoch 19/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0800 - accuracy: 0.9733 - val_loss: 0.0816 - val_accuracy: 0.9800
# Epoch 20/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0804 - accuracy: 0.9733 - val_loss: 0.1586 - val_accuracy: 0.9400
# Epoch 21/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0657 - accuracy: 0.9867 - val_loss: 0.0959 - val_accuracy: 0.9600
# Epoch 22/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0619 - accuracy: 0.9733 - val_loss: 0.1040 - val_accuracy: 0.9600
# Epoch 23/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0576 - accuracy: 0.9867 - val_loss: 0.2057 - val_accuracy: 0.9200
# Epoch 24/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0725 - accuracy: 0.9800 - val_loss: 0.2688 - val_accuracy: 0.8800
# Epoch 25/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0680 - accuracy: 0.9733 - val_loss: 0.1056 - val_accuracy: 0.9800
# Epoch 26/50
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0410 - accuracy: 0.9867 - val_loss: 0.1556 - val_accuracy: 0.9200
# Epoch 27/50
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0897 - accuracy: 0.9733 - val_loss: 0.0704 - val_accuracy: 0.9800
# Epoch 28/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0742 - accuracy: 0.9667 - val_loss: 0.0466 - val_accuracy: 0.9800
# Epoch 29/50
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0387 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9800
# Epoch 30/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0573 - accuracy: 0.9733 - val_loss: 0.0585 - val_accuracy: 0.9600
# Epoch 31/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0416 - accuracy: 0.9800 - val_loss: 0.0244 - val_accuracy: 1.0000
# Epoch 32/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0424 - accuracy: 0.9933 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 33/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0571 - accuracy: 0.9800 - val_loss: 0.2905 - val_accuracy: 0.9200
# Epoch 34/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0910 - accuracy: 0.9667 - val_loss: 0.1318 - val_accuracy: 0.9600
# Epoch 35/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0585 - accuracy: 0.9800 - val_loss: 0.1492 - val_accuracy: 0.9400
# Epoch 36/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0348 - accuracy: 0.9933 - val_loss: 0.1529 - val_accuracy: 0.9400
# Epoch 37/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0460 - accuracy: 0.9933 - val_loss: 0.0737 - val_accuracy: 0.9600
# Epoch 38/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0428 - accuracy: 0.9867 - val_loss: 0.0635 - val_accuracy: 0.9800
# Epoch 39/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0383 - accuracy: 0.9867 - val_loss: 0.0676 - val_accuracy: 0.9600
# Epoch 40/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0386 - accuracy: 0.9933 - val_loss: 0.1307 - val_accuracy: 0.9400
# Epoch 41/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0430 - accuracy: 0.9867 - val_loss: 0.1397 - val_accuracy: 0.9600
# Epoch 42/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 0.9800
# Epoch 43/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0411 - accuracy: 0.9933 - val_loss: 0.0979 - val_accuracy: 0.9600
# Epoch 44/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9800
# Epoch 45/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0252 - accuracy: 0.9933 - val_loss: 0.0912 - val_accuracy: 0.9600
# Epoch 46/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0341 - accuracy: 0.9933 - val_loss: 0.0427 - val_accuracy: 0.9800
# Epoch 47/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0293 - accuracy: 0.9867 - val_loss: 0.0254 - val_accuracy: 1.0000
# Epoch 48/50
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0417 - accuracy: 0.9800 - val_loss: 0.1337 - val_accuracy: 0.9400
# Epoch 49/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.9200
# Epoch 50/50
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0272 - accuracy: 0.9933 - val_loss: 0.0389 - val_accuracy: 0.9800
